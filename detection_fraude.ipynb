# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Bank_transaction_scenario1.csv', sep = ';')

# %%
df.head()
# Out:
#    ID Clients  Numero de compte Identifiant operation    Type de transaction  \
# 0        1023          851032.0            TR208/1145      Paiement en ligne
# 1         543           85453.0            TR107/0124                    ATM
# 2        1013          851301.0           TR205/00196  Paiement électronique
# 3       10360         8501036.0           TR216/00239                    ATM
# 4        1022          851202.0            TR208/0023                    ATM
#
#   Status operation Localisation                 Date   Montant   Target
# 0           Echoué      Kaolack  2025-02-10 22:20:00   45000.0   Normal
# 1           Echoué  Tambacounda  2025-02-10 17:00:00   18000.0  Suspect
# 2           Validé        Thiès  2025-02-10 03:30:00  200000.0   Normal
# 3           Validé      Kaolack  2025-02-09 09:00:00   29000.0   Normal
# 4           Validé   Ziguinchor  2025-02-08 15:55:00   14000.0   Normal

# %%
df.duplicate
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4688\2763212410.py in ?()
# ----> 1 df.duplicate
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'duplicate'
